# %%
import pandas as pd     #(version 1.0.0)
import plotly           #(version 4.5.4) pip install plotly==4.5.4
import plotly.express as px
import plotly.graph_objs as go

import dash             #(version 1.9.1) pip install dash==1.9.1
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from datetime import datetime as dt

app = dash.Dash(__name__)

# %%
df = pd.read_csv("patients-maroc.csv")
df
# Out:
#          n     sex   age country             province  disease  group  \
# 0        0    male  39.0   Maroc  Casablanca - Settat      NaN    NaN
# 1        1  female  89.0   Maroc  Casablanca - Settat      1.0    NaN
# 2        2    male  59.0  France     Marrakech - Safi      NaN    NaN
# 3        3  female   NaN  France     Marrakech - Safi      NaN    NaN
# 4        4  female   1.0  France     Marrakech - Safi      NaN    NaN
# ...    ...     ...   ...     ...                  ...      ...    ...
# 1179  1179     NaN   NaN     NaN    Daraa - Tafilalet      NaN    NaN
# 1180  1180     NaN   NaN     NaN    Daraa - Tafilalet      NaN    NaN
# 1181  1181     NaN   NaN     NaN    Daraa - Tafilalet      NaN    NaN
# 1182  1182     NaN   NaN     NaN    Daraa - Tafilalet      NaN    NaN
# 1183  1183     NaN   NaN     NaN    Daraa - Tafilalet      NaN    NaN
#
#      exposure_start exposure_end infection_reason  infection_order  \
# 0               NaN          NaN         Imported              NaN
# 1               NaN          NaN         Imported              NaN
# 2            3/7/20          NaN         Imported              NaN
# 3            3/7/20          NaN         Imported              NaN
# 4            3/7/20          NaN         Imported              NaN
# ...             ...          ...              ...              ...
# 1179            NaN          NaN            Local              NaN
# 1180            NaN          NaN            Local              NaN
# 1181            NaN          NaN            Local              NaN
# 1182            NaN          NaN            Local              NaN
# 1183            NaN          NaN            Local              NaN
#
#       infected_by  contact_number confirmed_date released_date deceased_date  \
# 0             NaN             NaN         3/2/20       3/17/20           NaN
# 1             NaN             NaN         3/5/20           NaN       3/10/20
# 2             NaN             NaN        3/10/20       3/29/20           NaN
# 3             NaN             NaN        3/11/20       3/29/20           NaN
# 4             NaN             NaN        3/11/20       3/29/20           NaN
# ...           ...             ...            ...           ...           ...
# 1179          NaN             NaN         4/7/20           NaN           NaN
# 1180          NaN             NaN         4/7/20           NaN           NaN
# 1181          NaN             NaN         4/7/20           NaN           NaN
# 1182          NaN             NaN         4/7/20           NaN           NaN
# 1183          NaN             NaN         4/7/20           NaN           NaN
#
#          state
# 0         Exit
# 1     Deceased
# 2         Exit
# 3         Exit
# 4         Exit
# ...        ...
# 1179  isolated
# 1180  isolated
# 1181  isolated
# 1182  isolated
# 1183  isolated
#
# [1184 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
import plotly.offline as pyo
import seaborn as sns

pyo.plot([{
    'x':df.state,
    'y':df.n
    
}])
# Out:
# 'temp-plot.html'
